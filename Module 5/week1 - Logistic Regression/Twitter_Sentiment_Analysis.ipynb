# %% [markdown]
# ##1. Tải bộ dữ liệu

# %%
# !gdown 1dANzxlEjeCEbveFOWWqzSG-niVx-vCgK
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1dANzxlEjeCEbveFOWWqzSG-niVx-vCgK
# To: /content/sentiment_analysis.csv
# 100% 1.10M/1.10M [00:00<00:00, 12.4MB/s]

# %% [markdown]
# ##2. Import thư viện cần thiết

# %%
import pandas as pd
import numpy as np
import re
import nltk
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from nltk.tokenize import TweetTokenizer
from collections import defaultdict

# %% [markdown]
# ##3. Đọc bộ dữ liệu

# %%
dataset_path = '/content/sentiment_analysis.csv'
df = pd.read_csv(dataset_path, index_col='id')
df
# Out:
#       label                                              tweet
# id
# 1         0  #fingerprint #Pregnancy Test https://goo.gl/h1...
# 2         0  Finally a transparant silicon case ^^ Thanks t...
# 3         0  We love this! Would you go? #talk #makememorie...
# 4         0  I'm wired I know I'm George I was made that wa...
# 5         1  What amazing service! Apple won't even talk to...
# ...     ...                                                ...
# 7916      0  Live out loud #lol #liveoutloud #selfie #smile...
# 7917      0  We would like to wish you an amazing day! Make...
# 7918      0  Helping my lovely 90 year old neighbor with he...
# 7919      0  Finally got my #smart #pocket #wifi stay conne...
# 7920      0  Apple Barcelona!!! #Apple #Store #BCN #Barcelo...
#
# [7920 rows x 2 columns]

# %% [markdown]
# ##4. Tiền xử lý bộ dữ liệu

# %%
def text_normalize(text):
    # Retweet old acronum "RT" removal
    text = re.sub(r'^RT[\s]+', '', text)

    # Hyperlinks removal
    text = re.sub(r'https?:\/\/.*[\r\n]*', '', text)

    # Hashtags removal
    text = re.sub(r'#', '', text)

    # Punctuation removal
    text = re.sub(r'[^\w\s]', '', text)

    # Tokenization
    tokenizer = TweetTokenizer(preserve_case=False, strip_handles=True, reduce_len=True)
    return tokenizer.tokenize(text)

# %%
def get_freqs(df):
    freqs = defaultdict(lambda: 0)
    for idx, row in df.iterrows():
        tweet = row['tweet']
        label = row['label']

        tokens = text_normalize(tweet)
        for token in tokens:
            pair = (token, label)
            freqs[pair] += 1
    return freqs

# %%
freqs = get_freqs(df)
freqs
# Out:
# defaultdict(<function __main__.get_freqs.<locals>.<lambda>()>,
#             {('fingerprint', 0): 4,
#              ('pregnancy', 0): 1,
#              ('test', 0): 8,
#              ('finally', 0): 168,
#              ('a', 0): 727,
#              ('transparant', 0): 1,
#              ('silicon', 0): 1,
#              ('case', 0): 228,
#              ('thanks', 0): 94,
#              ('to', 0): 876,
#              ('my', 0): 1227,
#              ('uncle', 0): 4,
#              ('yay', 0): 63,
#              ('sony', 0): 701,
#              ('xperia', 0): 54,
#              ('s', 0): 38,
#              ('sonyexperias', 0): 1,
#              ('we', 0): 159,
#              ('love', 0): 385,
#              ('this', 0): 456,
#              ('would', 0): 95,
#              ('you', 0): 557,
#              ('go', 0): 67,
#              ('talk', 0): 12,
#              ('makememories', 0): 1,
#              ('unplug', 0): 2,
#              ('relax', 0): 31,
#              ('iphone', 0): 2905,
#              ('smartphone', 0): 61,
#              ('wifi', 0): 36,
#              ('connect', 0): 1,
#              ('im', 0): 182,
#              ('wired', 0): 4,
#              ('i', 0): 1046,
#              ('know', 0): 58,
#              ('george', 0): 1,
#              ('was', 0): 68,
#              ('made', 0): 46,
#              ('that', 0): 153,
#              ('way', 0): 32,
#              ('cute', 0): 261,
#              ('daventry', 0): 1,
#              ('home', 0): 116,
#              ('what', 1): 72,
#              ('amazing', 1): 7,
#              ('service', 1): 25,
#              ('apple', 1): 1258,
#              ('wont', 1): 71,
#              ('even', 1): 53,
#              ('talk', 1): 3,
#              ('to', 1): 990,
#              ('me', 1): 267,
#              ('about', 1): 72,
#              ('a', 1): 589,
#              ('question', 1): 1,
#              ('i', 1): 964,
#              ('have', 1): 272,
#              ('unless', 1): 3,
#              ('pay', 1): 29,
#              ('them', 1): 58,
#              ('1995', 1): 1,
#              ('for', 1): 410,
#              ('their', 1): 48,
#              ('stupid', 1): 56,
#              ('support', 1): 18,
#              ('iphone', 1): 619,
#              ('software', 1): 23,
#              ('update', 1): 131,
#              ('fucked', 1): 17,
#              ('up', 1): 108,
#              ('my', 1): 1028,
#              ('phone', 1): 386,
#              ('big', 1): 25,
#              ('time', 1): 96,
#              ('iphones', 1): 32,
#              ('happy', 0): 231,
#              ('for', 0): 617,
#              ('us', 0): 46,
#              ('instapic', 0): 59,
#              ('instadaily', 0): 72,
#              ('xperiaz', 0): 24,
#              ('new', 0): 919,
#              ('type', 0): 7,
#              ('c', 0): 9,
#              ('charger', 0): 30,
#              ('cable', 0): 15,
#              ('uk', 0): 20,
#              ('bout', 0): 3,
#              ('shopping', 0): 53,
#              ('again', 0): 28,
#              ('listening', 0): 7,
#              ('music', 0): 181,
#              ('justme', 0): 4,
#              ('likeforlike', 0): 16,
#              ('followforfollow', 0): 6,
#              ('photo', 0): 281,
#              ('fun', 0): 199,
#              ('selfie', 0): 156,
#              ('pool', 0): 6,
#              ('water', 0): 24,
#              ('camera', 0): 119,
#              ('picoftheday', 0): 115,
#              ('sun', 0): 62,
#              ('instagood', 0): 239,
#              ('boy', 0): 58,
#              ('outdoor', 0): 3,
#              ('hey', 1): 25,
#              ('when', 1): 123,
#              ('you', 1): 395,
#              ('make', 1): 57,
#              ('new', 1): 182,
#              ('ipod', 1): 120,
#              ('dont', 1): 111,
#              ('it', 1): 488,
#              ('color', 1): 3,
#              ('or', 1): 73,
#              ('2inches', 1): 1,
#              ('thinner', 1): 2,
#              ('not', 1): 202,
#              ('crash', 1): 9,
#              ('every', 1): 44,
#              ('five', 1): 3,
#              ('fuckin', 1): 3,
#              ('minite', 1): 1,
#              ('ha', 1): 3,
#              ('heavy', 1): 1,
#              ('machinery', 1): 1,
#              ('but', 1): 138,
#              ('does', 1): 46,
#              ('need', 1): 55,
#              ('really', 1): 49,
#              ('dropped', 1): 9,
#              ('the', 1): 875,
#              ('ball', 1): 3,
#              ('with', 1): 164,
#              ('that', 1): 184,
#              ('design', 1): 4,
#              ('drinkyourhaterade', 1): 1,
#              ('contemplating', 1): 1,
#              ('giving', 1): 5,
#              ('in', 1): 263,
#              ('bandwagon', 1): 1,
#              ('simply', 1): 2,
#              ('because', 1): 68,
#              ('cellcom', 1): 1,
#              ('has', 1): 80,
#              ('no', 1): 121,
#              ('androids', 1): 1,
#              ('depressing', 1): 3,
#              ('idontwantto', 1): 1,
#              ('just', 0): 235,
#              ('another', 0): 31,
#              ('crazy', 0): 30,
#              ('purchase', 0): 5,
#              ('lol', 0): 96,
#              ('theory', 0): 1,
#              ('is', 0): 433,
#              ('work', 0): 125,
#              ('hard', 0): 34,
#              ('play', 0): 31,
#              ('ipad', 0): 244,
#              ('apple', 0): 1393,
#              ('shaqlockholmes', 1): 1,
#              ('sam_louise', 1): 1,
#              ('1991', 1): 1,
#              ('battery', 1): 48,
#              ('is', 1): 450,
#              ('so', 1): 233,
#              ('painful', 1): 1,
#              ('charge', 1): 28,
#              ('overnight', 1): 2,
#              ('and', 1): 589,
#              ('by', 1): 47,
#              ('lunchtime', 1): 1,
#              ('dead', 1): 14,
#              ('hateorange', 1): 2,
#              ('from', 0): 179,
#              ('deepellum', 0): 1,
#              ('towards', 0): 2,
#              ('downtown', 0): 4,
#              ('dallas', 0): 1,
#              ('bigd', 0): 1,
#              ('saturday', 0): 40,
#              ('rx100m3', 0): 1,
#              ('summer', 0): 115,
#              ('urban', 0): 8,
#              ('like', 0): 352,
#              ('and', 0): 649,
#              ('share', 0): 41,
#              ('if', 0): 102,
#              ('want', 0): 67,
#              ('3d', 0): 15,
#              ('phone', 0): 516,
#              ('iphonesia', 0): 133,
#              ('instagram', 0): 334,
#              ('photooftheday', 0): 184,
#              ('tweegram', 0): 50,
#              ('reason', 1): 25,
#              ('one', 1): 97,
#              ('suck', 1): 64,
#              ('truth', 1): 3,
#              ('truthbetold', 1): 1,
#              ('agree', 1): 7,
#              ('fact', 1): 17,
#              ('realitycheck', 1): 1,
#              ('blackberrypictwittercomzpggd', 1): 1,
#              ('7cazn', 1): 1,
#              ('how', 1): 78,
#              ('store', 1): 36,
#              ('gunna', 1): 3,
#              ('be', 1): 112,
#              ('out', 1): 99,
#              ('of', 1): 328,
#              ('5c', 1): 5,
#              ('screens', 1): 4,
#              ('its', 1): 161,
#              ('monday', 1): 6,
#              ('ur', 1): 10,
#              ('fucking', 1): 118,
#              ('fuckingpissed', 1): 1,
#              ('art', 0): 102,
#              ('easter', 0): 9,
#              ('dear', 0): 17,
#              ('friends', 0): 117,
#              ('be', 0): 153,
#              ('published', 0): 1,
#              ('on', 0): 385,
#              ('channel', 0): 3,
#              ('design', 0): 35,
#              ('face', 0): 34,
#              ('the', 0): 1104,
#              ('bunny', 0): 5,
#              ('email', 0): 7,
#              ('it', 0): 447,
#              ('me', 0): 681,
#              ('as', 0): 82,
#              ('png', 0): 1,
#              ('thumbnail', 0): 1,
#              ('mutitaedibleartgmailcompictwittercom', 0): 1,
#              ('7jhwphfbgt', 0): 1,
#              ('excuse', 0): 2,
#              ('waiter', 0): 1,
#              ('there', 0): 36,
#              ('seems', 0): 1,
#              ('pie', 0): 25,
#              ('in', 0): 433,
#              ('soup', 0): 3,
#              ('wife', 0): 11,
#              ('bake', 0): 1,
#              ('an', 0): 187,
#              ('ive', 1): 60,
#              ('had', 1): 68,
#              ('this', 1): 214,
#              ('four', 1): 4,
#              ('days', 1): 23,
#              ('button', 1): 19,
#              ('on', 1): 342,
#              ('back', 1): 63,
#              ('broke', 1): 22,
#              ('accidentally', 1): 3,
#              ('hit', 1): 5,
#              ('once', 1): 20,
#              ('your', 1): 146,
#              ('screen', 1): 44,
#              ('goes', 1): 12,
#              ('completely', 1): 12,
#              ('black', 1): 5,
#              ('keep', 1): 10,
#              ('getting', 1): 37,
#              ('texts', 1): 17,
#              ('all', 1): 193,
#              ('day', 1): 53,
#              ('cant', 1): 136,
#              ('check', 1): 8,
#              ('6thiphone', 1): 1,
#              ('its', 0): 149,
#              ('time', 0): 123,
#              ('wallpapers', 0): 7,
#              ('wall', 0): 6,
#              ('screen', 0): 49,
#              ('galaxy', 0): 261,
#              ('samsung', 0): 1162,
#              ('app', 0): 168,
#              ('105', 0): 2,
#              ('billion', 0): 1,
#              ('3', 0): 217,
#              ('patents', 0): 2,
#              ('where', 0): 13,
#              ('prior', 0): 1,
#              ('300', 0): 4,
#              ('millions', 0): 3,
#              ('each', 0): 6,
#              ('patent', 0): 5,
#              ('trolls', 0): 2,
#              ('are', 0): 109,
#              ('partying', 0): 1,
#              ('now', 0): 217,
#              ('messed', 1): 6,
#              ('havent', 1): 12,
#              ('done', 1): 13,
#              ('nothing', 1): 22,
#              ('myloss', 1): 1,
#              ('touch', 1): 6,
#              ('frozen', 1): 3,
#              ('logo', 1): 5,
#              ('starts', 1): 5,
#              ('if', 1): 103,
#              ('lose', 1): 8,
#              ('demis', 1): 1,
#              ('music', 1): 55,
#              ('pics', 1): 6,
#              ('will', 1): 76,
#              ('kill', 1): 5,
#              ('someone', 1): 22,
#              ('soangry', 1): 2,
#              ('hateapple', 1): 46,
#              ('do', 0): 70,
#              ('flower', 0): 28,
#              ('green', 0): 38,
#              ('diamond', 0): 7,
#              ('pearls', 0): 4,
#              ('4s', 0): 45,
#              ('must', 0): 159,
#              ('watch', 0): 59,
#              ('youtube', 0): 25,
#              ('subscribe', 0): 10,
#              ('daily', 0): 16,
#              ('vlog', 0): 7,
#              ('twitch', 0): 15,
#              ('gaming', 0): 52,
#              ('ps4', 0): 100,
#              ('xbox', 0): 25,
#              ('games', 0): 58,
#              ('ios', 0): 169,
#              ('android', 0): 179,
#              ('thank', 0): 76,
#              ('live', 0): 108,
#              ('laugh', 0): 54,
#              ('life', 0): 300,
#              ('food', 0): 58,
#              ('philippines', 0): 3,
#              ('instago', 0): 34,
#              ('instahub', 0): 28,
#              ('ch', 0): 1,
#              ('cannon', 0): 1,
#              ('suewee', 0): 2,
#              ('friendship', 0): 11,
#              ('americanbully', 0): 2,
#              ('dog', 0): 50,
#              ('piggies', 0): 1,
#              ('family', 0): 132,
#              ('southerncharm', 0): 1,
#              ('americanidol', 0): 1,
#              ('goals', 0): 12,
#              ('bestfriends', 0): 10,
#              ('pitbull', 0): 6,
#              ('iphonex', 0): 163,
#              ('onelove', 0): 4,
#              ('country', 0): 5,
#              ('muscle', 0): 3,
#              ('nfl', 0): 3,
#              ('worldwide', 0): 3,
#              ('america', 0): 11,
#              ('bigboy', 0): 3,
#              ('thislife', 0): 1,
#              ('tmz', 0): 3,
#              ('wild', 0): 8,
#              ('hoggpictwittercom', 0): 1,
#              ('1mn5ogpi2c', 0): 1,
#              ('by', 0): 100,
#              ('mimmoal', 0): 6,
#              ('feb', 0): 3,
#              ('2016', 0): 36,
#              ('taken', 0): 29,
#              ('with', 0): 434,
#              ('rx100', 0): 6,
#              ('direzioneverticale', 0): 1,
#              ('sunset', 0): 60,
#              ('sky', 0): 50,
#              ('beautiful', 0): 197,
#              ('pictwittercomcxifijj', 0): 1,
#              ('54g', 0): 1,
#              ('so', 0): 245,
#              ('sister', 0): 20,
#              ('bought', 0): 43,
#              ('early', 0): 32,
#              ('bday', 0): 14,
#              ('gift', 0): 113,
#              ('s4', 0): 68,
#              ('received', 0): 6,
#              ('note', 0): 148,
#              ('2', 0): 191,
#              ('many', 0): 11,
#              ('cottds', 0): 1,
#              ('nswrl', 0): 1,
#              ('market', 0): 10,
#              ('pipeline', 0): 1,
#              ('why', 1): 127,
#              ('delete', 1): 20,
#              ('individual', 1): 2,
#              ('songs', 1): 16,
#              ('from', 1): 98,
#              ('itunes', 1): 136,
#              ('everybody', 1): 2,
#              ('freaking', 1): 12,
#              ('ios', 1): 170,
#              ('7', 1): 75,
#              ('im', 1): 127,
#              ('here', 1): 16,
#              ('like', 1): 105,
#              ('duuude', 1): 1,
#              ('windows', 1): 25,
#              ('phones', 1): 24,
#              ('are', 1): 113,
#              ('more', 1): 61,
#              ('advanced', 1): 3,
#              ('than', 1): 42,
#              ('customization', 1): 1,
#              ('5s', 1): 7,
#              ('s', 1): 19,
#              ('standing', 1): 3,
#              ('sirriiously', 1): 1,
#              ('bad', 1): 14,
#              ('c', 1): 1,
#              ('cheap', 1): 3,
#              ('same', 1): 19,
#              ('res', 1): 1,
#              ('camera', 1): 14,
#              ('tech', 1): 14,
#              ('no', 0): 78,
#              ('bull', 0): 3,
#              ('instasize', 0): 5,
#              ('leggings', 0): 1,
#              ('lightskin', 0): 1,
#              ('curlyhair', 0): 1,
#              ('bellypiercing', 0): 1,
#              ('smile', 0): 206,
#              ('potd', 0): 12,
#              ('they', 0): 63,
#              ('dint', 0): 2,
#              ('create', 0): 3,
#              ('dont', 0): 60,
#              ('let', 0): 18,
#              ('them', 0): 28,
#              ('destroy', 0): 2,
#              ('candid', 0): 5,
#              ('sunday', 0): 55,
#              ('sundayvibes', 0): 2,
#              ('always', 0): 42,
#              ('eyes', 0): 21,
#              ('ootd', 0): 21,
#              ('fashion', 0): 107,
#              ('blackandwhite', 0): 22,
#              ('poser', 0): 4,
#              ('attitude', 0): 1,
#              ('lifeisgood', 0): 1,
#              ('mylook', 0): 1,
#              ('mylife', 0): 7,
#              ('photoeveryday', 0): 1,
#              ('lookoftheday', 0): 4,
#              ('latepost', 0): 4,
#              ('mylifepictwittercommmhcqyad', 0): 1,
#              ('9b', 0): 1,
#              ('film', 0): 19,
#              ('set', 0): 14,
#              ('building', 0): 5,
#              ('timelapse', 0): 4,
#              ('video', 0): 45,
#              ('producer', 0): 13,
#              ('videoproduction', 0): 5,
#              ('follow', 0): 692,
#              ('commercial', 0): 8,
#              ('actor', 0): 7,
#              ('actress', 0): 6,
#              ('hollywood', 0): 4,
#              ('losangeles', 0): 7,
#              ('movies', 0): 15,
#              ('acting', 0): 4,
#              ('startup', 0): 5,
#              ('startupvideos', 0): 2,
#              ('shotoniphonpictwittercom', 0): 1,
#              ('94eceiaine', 0): 1,
#              ('cupcakes', 0): 4,
#              ('wallpaper', 0): 15,
#              ('pink', 0): 79,
#              ('sweet', 0): 75,
#              ('cherries', 0): 1,
#              ('eeee', 0): 1,
#              ('sexy', 0): 37,
#              ('ladies', 0): 5,
#              ('iphon', 0): 7,
#              ('acquisto', 0): 1,
#              ('del', 0): 1,
#              ('week', 0): 30,
#              ('end', 0): 12,
#              ('8', 0): 92,
#              ('8p', 0): 9,
#              ('lus', 0): 9,
#              ('gril', 0): 3,
#              ('moment', 0): 22,
#              ('italy', 0): 23,
#              ('majestic', 0): 2,
#              ('see', 0): 36,
#              ('differently', 0): 1,
#              ('photography', 0): 154,
#              ('nature', 0): 75,
#              ('landscape', 0): 14,
#              ('forest', 0): 3,
#              ('hidden', 0): 2,
#              ('clearing', 0): 1,
#              ('view', 0): 12,
#              ('woods', 0): 2,
#              ('tree', 0): 27,
#              ('travel', 0): 54,
#              ('biker', 0): 1,
#              ('a7', 0): 10,
#              ('ziess', 0): 1,
#              ('instgramhub', 0): 1,
#              ('google', 1): 13,
#              ('cut', 1): 9,
#              ('get', 1): 156,
#              ('program', 1): 6,
#              ('ahhh', 0): 7,
#              ('look', 0): 90,
#              ('what', 0): 94,
#              ('got', 0): 203,
#              ('christmas', 0): 112,
#              ('girl', 0): 162,
#              ('instacool', 0): 22,
#              ('20likes', 0): 1,
#              ('bitcoinboy', 0): 1,
#              ('ipod', 0): 78,
#              ('free', 0): 101,
#              ('game', 0): 100,
#              ('kansas', 0): 2,
#              ('georgia', 0): 3,
#              ('ogochocinco', 0): 1,
#              ('talking', 0): 5,
#              ('antoine', 0): 3,
#              ('check', 0): 55,
#              ('out', 0): 151,
#              ('106', 0): 2,
#              ('ent', 0): 1,
#              ('appstore', 0): 30,
#              ('all', 0): 167,
#              ('at', 0): 265,
#              ('once', 0): 5,
#              ('joy', 0): 33,
#              ('peace', 0): 31,
#              ('reflect', 0): 7,
#              ('remember', 0): 8,
#              ('cloud', 0): 10,
#              ('cloudhub', 0): 5,
#              ('skyhub', 0): 5,
#              ('gr', 0): 8,
#              ('baby', 0): 133,
#              ('babyboy', 0): 2,
#              ('muesli', 0): 2,
#              ('hedgehog', 0): 1,
#              ('pet', 0): 16,
#              ('him', 0): 22,
#              ('7', 0): 107,
#              ('inbox', 0): 2,
#              ('letters', 0): 2,
#              ('editor', 0): 1,
#              ('news', 0): 109,
#              ('health', 0): 15,
#              ('fail', 0): 12,
#              ('tech', 0): 79,
#              ('funny', 0): 61,
#              ('lolpictwittercomik', 0): 1,
#              ('1rhumovz', 0): 1,
#              ('zsofimonster', 0): 1,
#              ('thinner', 0): 1,
#              ('faster', 0): 4,
#              ('amazing', 0): 166,
#              ('hated', 0): 1,
#              ('will', 0): 91,
#              ('getting', 0): 27,
#              ('one', 0): 113,
#              ('ye', 0): 6,
#              ('jamesdawute', 0): 1,
#              ('tablets', 0): 10,
#              ('but', 0): 85,
#              ('personally', 0): 2,
#              ('have', 0): 158,
#              ('use', 0): 38,
#              ('sense', 0): 3,
#              ('not', 0): 109,
#              ('fan', 0): 13,
#              ('think', 0): 37,
#              ('quite', 0): 5,
#              ('gd', 0): 2,
#              ('product', 0): 18,
#              ('why', 0): 56,
#              ('black', 0): 86,
#              ('friday', 0): 56,
#              ('called', 0): 6,
#              ('seriously', 1): 32,
#              ('afraid', 1): 1,
#              ('profit', 1): 1,
#              ('going', 1): 54,
#              ('into', 1): 19,
#              ('elses', 1): 2,
#              ('pocket', 1): 1,
#              ('where', 1): 19,
#              ('other', 1): 20,
#              ('chargers', 1): 27,
#              ('arent', 1): 6,
#              ('supported', 1): 5,
#              ('at', 1): 108,
#              ('18', 1): 3,
#              ('pos', 1): 6,
#              ('charger', 1): 65,
#              ('month', 1): 17,
#              ('after', 1): 49,
#              ('good', 1): 31,
#              ('job', 1): 13,
#              ('having', 1): 23,
#              ('actually', 1): 21,
#              ('killing', 1): 5,
#              ('am', 1): 35,
#              ('paying', 1): 7,
#              ('209', 1): 1,
#              ('replacement', 1): 5,
#              ('thats', 1): 27,
#              ('still', 1): 66,
#              ('programmed', 1): 3,
#              ('basic', 1): 4,
#              ('rt', 1): 21,
#              ('sloan_lovescudi', 1): 1,
#              ('sucks', 1): 34,
#              ('droid', 1): 8,
#              ('waitwhat', 0): 1,
#              ('double', 0): 5,
#              ('saw', 0): 6,
#              ('alyssa', 0): 1,
#              ('4h', 0): 2,
#              ('cool', 0): 103,
#              ('picture', 0): 37,
#              ('l', 0): 11,
#              ('cycle', 0): 2,
#              ('of', 0): 388,
#              ('complete', 0): 7,
#              ('froot', 0): 1,
#              ('run', 0): 12,
#              ('beach', 0): 48,
#              ('sport', 0): 12,
#              ('tysonj', 0): 1,
#              ('thats', 0): 23,
#              ('bit', 0): 13,
#              ('hypocritical', 0): 1,
#              ('hashtag', 0): 14,
#              ('yet', 0): 10,
#              ('quivering', 0): 1,
#              ('anticipation', 0): 1,
#              ('arrival', 0): 2,
#              ('your', 0): 216,
#              ('gain', 0): 308,
#              ('followers', 0): 158,
#              ('rt', 0): 246,
#              ('back', 0): 225,
#              ('everyone', 0): 170,
#              ('who', 0): 201,
#              ('rts', 0): 147,
#              ('sougofollow', 0): 165,
#              ('ff', 0): 34,
#              ('i7si', 0): 1,
#              ('geometry', 0): 1,
#              ('iphoneography', 0): 50,
#              ('iphoneonly', 0): 76,
#              ('2018', 0): 44,
#              ('streetphotography', 0): 9,
#              ('iphonephotography', 0): 14,
#              ('mobilephotography', 0): 5,
#              ('mobile', 0): 74,
#              ('colors', 0): 16,
#              ('bright', 0): 17,
#              ('users', 0): 14,
#              ('more', 0): 102,
#              ('can', 0): 83,
#              ('less', 0): 14,
#              ('random', 0): 37,
#              ('instamood', 0): 95,
#              ('loljk', 0): 1,
#              ('shine', 0): 9,
#              ('wine', 0): 9,
#              ('amaliexmaria', 0): 1,
#              ('copenhagen', 0): 5,
#              ('creative', 0): 16,
#              ('composer', 0): 5,
#              ('denmark', 0): 7,
#              ('f4f', 0): 18,
#              ('hot', 0): 51,
#              ('iconic', 0): 6,
#              ('keepthefaith', 0): 5,
#              ('l4l', 0): 18,
#              ('mariajensen', 0): 5,
#              ('original', 0): 12,
#              ('pop', 0): 19,
#              ('red', 0): 67,
#              ('rock', 0): 12,
#              ('soul', 0): 12,
#              ('singer', 0): 13,
#              ('songwriter', 0): 6,
#              ('song', 0): 25,
#              ('universal', 0): 9,
#              ('warnerpictwittercomgbeusyed', 0): 1,
#              ('5m', 0): 1,
#              ('tescophoneshop', 0): 1,
#              ('wedding', 0): 25,
#              ('dvd', 0): 2,
#              ('which', 0): 11,
#              ('thought', 0): 13,
#              ('id', 0): 18,
#              ('lost', 0): 15,
#              ('days', 0): 34,
#              ('meliiecandy', 0): 1,
#              ('ipadmini', 0): 20,
#              ('soldes', 0): 1,
#              ('instamoment', 0): 5,
#              ('planeteig', 0): 1,
#              ('01', 0): 4,
#              ('or', 0): 53,
#              ('feeling', 0): 18,
#              ('when', 0): 83,
#              ('broken', 0): 7,
#              ('phones', 0): 35,
#              ('being', 0): 19,
#              ('replaced', 0): 10,
#              ('happiness', 0): 57,
#              ('pictwittercomygsuke', 0): 1,
#              ('2ces', 0): 1,
#              ('light', 0): 29,
#              ('please', 0): 22,
#              ('lamp', 0): 2,
#              ('pekanbaru', 0): 1,
#              ('riau', 0): 1,
#              ('indonesia', 0): 16,
#              ('a6000', 0): 31,
#              ('sonya', 0): 25,
#              ('6000', 0): 27,
#              ('acquisition', 0): 2,
#              ('5s', 0): 42,
#              ('gold', 0): 48,
#              ('brussels', 0): 3,
#              ('texted', 1): 1,
#              ('reset', 1): 15,
#              ('work', 1): 77,
#              ('again', 1): 63,
#              ('_', 1): 19,
#              ('sorry', 1): 14,
#              ('inception', 0): 1,
#              ('white', 0): 108,
#              ('tea', 0): 12,
#              ('chilling', 0): 13,
#              ('carcasa', 0): 1,
#              ('clear', 0): 4,
#              ('cover', 0): 57,
#              ('para', 0): 1,
#              ('grandprime', 0): 1,
#              ('felizdomingo', 0): 1,
#              ('samsunggalaxy', 0): 15,
#              ('g530', 0): 1,
#              ('felizlunes', 0): 1,
#              ('felizsemana', 0): 1,
#              ('2oct', 0): 1,
#              ('3oct', 0): 1,
#              ('felizmartespictwittercomxtldsjwpz', 0): 1,
#              ('9', 0): 19,
#              ('apples', 1): 19,
#              ('mighty', 1): 1,
#              ('mouse', 1): 3,
#              ('came', 1): 9,
#              ('2', 1): 61,
#              ('lithium', 1): 2,
#              ('aas', 1): 2,
#              ('magic', 1): 3,
#              ('comes', 1): 6,
#              ('alkaline', 1): 1,
#              ('20', 1): 19,
#              ('nyclesbians', 0): 1,
#              ('followsunday', 0): 30,
#              ('followback', 0): 52,
#              ('teamfollowback', 0): 32,
#              ('retweet', 0): 59,
#              ('keep', 0): 49,
#              ('doing', 0): 43,
#              ('ya', 0): 40,
#              ('thing', 0): 45,
#              ('samsunguk', 0): 3,
#              ('ive', 0): 28,
#              ('had', 0): 54,
#              ('tumble', 0): 1,
#              ('dryer', 0): 1,
#              ('4', 0): 173,
#              ('months', 0): 9,
#              ('been', 0): 37,
#              ('already', 0): 13,
#              ('same', 0): 14,
#              ('problem', 0): 7,
#              ('has', 0): 65,
#              ('occurred', 0): 1,
#              ('iwant', 0): 2,
#              ('issue', 0): 5,
#              ('resolved', 0): 1,
#              ('able', 0): 7,
#              ('return', 0): 3,
#              ('alexandraeton', 0): 1,
#              ('bbcwatchdog', 0): 1,
#              ('lilya', 0): 1,
#              ('_0716', 0): 1,
#              ('a7sll', 0): 1,
#              ('7s2', 0): 1,
#              ('throwback', 0): 2,
#              ('shoot', 0): 14,
#              ('blury', 0): 1,
#              ('pic', 0): 43,
#              ('photos', 0): 25,
#              ('pictwittercom', 0): 29,
#              ('3btew6b4kx', 0): 1,
#              ('cnet', 1): 1,
#              ('call', 1): 11,
#              ('put', 1): 35,
#              ('an', 1): 169,
#              ('absurd', 1): 2,
#              ('price', 1): 5,
#              ('device', 1): 14,
#              ('commonwealth', 0): 2,
#              ('skye', 0): 1,
#              ('nicolson', 0): 1,
#              ('wins', 0): 3,
#              ('boxing', 0): 1,
#              ('memory', 0): 7,
#              ('her', 0): 41,
#              ('dead', 0): 5,
#              ('brothers', 0): 6,
#              ('adaptive', 0): 1,
#              ('galatasaray', 0): 1,
#              ('iherborder', 0): 1,
#              ('presidenttrump', 0): 1,
#              ('oh', 1): 20,
#              ('dear', 1): 30,
#              ('joy', 1): 2,
#              ('5', 1): 60,
#              ('any', 1): 36,
#              ('comment', 1): 1,
#              ('just', 1): 204,
#              ('lip', 1): 1,
#              ('win', 1): 4,
#              ('getalife', 1): 1,
#              ('tecshit', 1): 1,
#              ('enjoying', 0): 8,
#              ('ps3', 0): 50,
#              ('tombraider', 0): 1,
#              ('laracroft', 0): 1,
#              ('playstation', 0): 71,
#              ('gamer', 0): 38,
#              ('hunger', 0): 3,
#              ('simpsons', 0): 2,
#              ('thehungergames', 0): 1,
#              ('2012', 0): 19,
#              ('something', 0): 17,
#              ('wrong', 0): 5,
#              ('right', 0): 26,
#              ('today', 0): 209,
#              ('makes', 0): 27,
#              ('item', 0): 3,
#              ('jammieexoxo', 0): 1,
#              ('recommends', 0): 1,
#              ('earphone', 0): 7,
#              ('earpods', 0): 2,
#              ('lifestyle', 0): 23,
#              ('fuckyou', 1): 66,
#              ('never', 1): 54,
#              ('ending', 1): 2,
#              ('bugs', 1): 4,
#              ('payed', 1): 1,
#              ('bucks', 1): 6,
#              ('phonehow', 1): 1,
#              ('little', 1): 7,
#              ('quality', 1): 4,
#              ('hereanotherangrycustomer', 1): 1,
#              ('girlfriend', 0): 12,
#              ('year', 0): 64,
#              ('gf', 0): 2,
#              ('bf', 0): 6,
#              ('card', 0): 11,
#              ('z', 0): 6,
#              ('soppy', 0): 1,
#              ('birthday', 0): 153,
#              ('present', 0): 59,
#              ('mom', 0): 33,
#              ('macbookpro', 0): 39,
#              ('macbook', 0): 75,
#              ('stockholm', 0): 3,
#              ('sweden', 0): 10,
#              ('compute', 0): 1,
#              ('quote', 0): 31,
#              ('day', 0): 309,
#              ('quotes', 0): 25,
#              ('wisdom', 0): 9,
#              ('words', 0): 17,
#              ('tweetgram', 0): 11,
#              ('applaud', 0): 1,
#              ('sheffield', 0): 1,
#              ('store', 0): 43,
#              ('customer', 0): 39,
#              ('service', 0): 18,
#              ('great', 0): 68,
#              ('quality', 0): 9,
#              ('repair', 0): 7,
#              ('done', 0): 24,
#              ('few', 0): 11,
#              ('hour', 0): 10,
#              ('lost', 1): 39,
#              ('everything', 1): 48,
#              ('due', 1): 7,
#              ('recovery', 1): 6,
#              ('mode', 1): 8,
#              ('mashable', 1): 3,
#              ('hater', 1): 2,
#              ('yousuck', 1): 9,
#              ('briantong', 1): 1,
#              ('easytotalk', 1): 1,
#              ('producesomething', 1): 1,
#              ('usa', 1): 3,
#              ('company', 1): 20,
#              ('korean', 1): 1,
#              ('samsung', 1): 109,
#              ('fan', 1): 4,
#              ('loser', 1): 1,
#              ('thanks', 1): 49,
#              ('working', 1): 41,
#              ('servers', 1): 3,
#              ('sony', 1): 82,
#              ('dumb', 1): 9,
#              ('scheduled', 1): 1,
#              ('maintenance', 1): 2,
#              ('today', 1): 26,
#              ('models', 0): 4,
#              ('byhilalak', 0): 1,
#              ('earphones', 0): 6,
#              ('urbanears', 0): 1,
#              ('handmade', 0): 5,
#              ('hayatinarenkkat', 0): 1,
#              ('itunes', 0): 64,
#              ('vicio', 0): 4,
#              ('nellyfurtado', 0): 1,
#              ('nelstar', 0): 1,
#              ('playingnow', 0): 1,
#              ('diva', 0): 4,
#              ('cds', 0): 2,
#              ('how', 0): 82,
#              ('features', 0): 18,
#              ('didnt', 0): 13,
#              ('box', 0): 5,
#              ('yey', 0): 7,
#              ('sonyxperiaz', 0): 4,
#              ('blessed', 0): 32,
#              ('feliz', 0): 5,
#              ('sábado', 0): 1,
#              ('con', 0): 5,
#              ('café', 0): 2,
#              ('coffee', 0): 34,
#              ('pantry', 0): 2,
#              ('dreamy', 0): 1,
#              ('effect', 0): 8,
#              ('created', 0): 4,
#              ('straight', 0): 2,
#              ('impressive', 0): 2,
#              ('spring', 0): 34,
#              ('blossom', 0): 4,
#              ('finallly', 0): 1,
#              ('here', 0): 79,
#              ('galaxynote', 0): 28,
#              ('awsome', 0): 5,
#              ('beamman', 0): 1,
#              ('best', 0): 121,
#              ('special', 0): 13,
#              ('valentine', 0): 17,
#              ('36', 0): 1,
#              ('erie', 0): 6,
#              ('pa', 0): 5,
#              ('car', 0): 25,
#              ('sign', 0): 6,
#              ('iloveyou', 0): 3,
#              ('lunch', 0): 11,
#              ('park', 0): 11,
#              ('carrot', 0): 5,
#              ('banana', 0): 13,
#              ('lovely', 0): 9,
#              ('dogs', 0): 18,
#              ('trees', 0): 7,
#              ('autumn', 0): 9,
#              ('leaves', 0): 8,
#              ('iphonethe', 0): 1,
#              ('confession', 0): 1,
#              ('spend', 0): 7,
#              ('confessing', 0): 2,
#              ...})

# %%
def get_feature(text, freqs):
    tokens = text_normalize(text)

    X = np.zeros(3)
    X[0] = 1
    for token in tokens:
        X[1] += freqs[(token, 1)]
        X[2] += freqs[(token, 0)]
    return X

# %%
X = []
y = []

freqs = get_freqs(df)
for idx, row in df.iterrows():
    tweet = row['tweet']
    label = row['label']

    X.append(get_feature(tweet, freqs))
    y.append(label)

X = np.array(X)
y = np.array(y)
print(X)
print(X.shape)
print(y)
print(y.shape)
# Out:
# [[1.000e+00 2.000e+00 1.300e+01]
#  [1.000e+00 2.788e+03 4.183e+03]
#  [1.000e+00 1.425e+03 4.768e+03]
#  ...
#  [1.000e+00 4.635e+03 6.175e+03]
#  [1.000e+00 1.959e+03 3.814e+03]
#  [1.000e+00 3.181e+03 6.160e+03]]
# (7920, 3)
# [0 0 0 ... 0 0 0]
# (7920,)

# %% [markdown]
# ##5. Chia bộ train, val, test

# %%
val_size = 0.2
test_size = 0.125
random_state = 2
is_shuffle = True

X_train, X_val, y_train, y_val = train_test_split(
    X, y,
    test_size=val_size,
    random_state=random_state,
    shuffle=is_shuffle
)

X_train, X_test, y_train, y_test = train_test_split(
    X_train, y_train,
    test_size=test_size,
    random_state=random_state,
    shuffle=is_shuffle
)

# %% [markdown]
# ##6. Chuẩn hóa dữ liệu

# %%
from sklearn.preprocessing import StandardScaler

normalizer = StandardScaler()
X_train[:, 1:] = normalizer.fit_transform(X_train[:, 1:])
X_val[:, 1:] = normalizer.transform(X_val[:, 1:])
X_test[:, 1:] = normalizer.transform(X_test[:, 1:])

# %% [markdown]
# ##7. Cài đặt các hàm quan trọng

# %%
# Hàm sigmoid:
def sigmoid(z):
    return 1 / (1 + np.exp(-z))

# Hàm dự đoán:
def predict(X, theta):
    dot_product = np.dot(X, theta)
    y_hat = sigmoid(dot_product)

    return y_hat

# Hàm tính loss:
def compute_loss(y_hat, y):
    y_hat = np.clip(y_hat, 1e-7, 1 - 1e-7)

    return (
        -y * np.log(y_hat) - (1 - y) * np.log(1 - y_hat)
    ).mean()

# Hàm tính gradient:
def compute_gradient(X, y, y_hat):
    return np.dot(X.T, (y_hat - y)) / y.size

# Hàm cập nhật trọng số:
def update_theta(theta, gradient, lr):
    return theta - lr * gradient

# Hàm tính độ chính xác:
def compute_accuracy(X, y, theta):
    y_hat = predict(X, theta).round()
    acc = (y_hat == y).mean()

    return acc

# %% [markdown]
# ##8. Khai báo các siêu tham số và khởi tạo weights

# %%
lr = 0.01
epochs = 200
batch_size = 128

np.random.seed(random_state)
theta = np.random.uniform(size=X_train.shape[1])

# %% [markdown]
# ##9. Huấn luyện mô hình

# %%
train_accs = []
train_losses = []
val_accs = []
val_losses = []

for epoch in range(epochs):
    train_batch_losses = []
    train_batch_accs = []
    val_batch_losses = []
    val_batch_accs = []

    for i in range(0, X_train.shape[0], batch_size):
        X_i = X_train[i:i + batch_size]
        y_i = y_train[i:i + batch_size]

        y_hat = predict(X_i, theta)

        train_loss = compute_loss(y_hat, y_i)
        gradient = compute_gradient(X_i, y_i, y_hat)
        theta = update_theta(theta, gradient, lr)

        train_batch_losses.append(train_loss)

    train_acc = compute_accuracy(X_train, y_train, theta)
    train_batch_accs.append(train_acc)

    y_val_hat = predict(X_val, theta)
    val_loss = compute_loss(y_val_hat, y_val)
    val_batch_losses.append(val_loss)

    val_acc = compute_accuracy(X_val, y_val, theta)
    val_batch_accs.append(val_acc)

    train_batch_loss = sum(train_batch_losses) / len(train_batch_losses)
    val_batch_loss = sum(val_batch_losses) / len(val_batch_losses)
    train_batch_acc = sum(train_batch_accs) / len(train_batch_accs)
    val_batch_acc = sum(val_batch_accs) / len(val_batch_accs)

    train_losses.append(train_batch_loss)
    val_losses.append(val_batch_loss)
    train_accs.append(train_batch_acc)
    val_accs.append(val_batch_acc)

    print(f'\nEPOCH {epoch + 1}:\tTraining loss: {train_batch_loss:.3f}\tValidation loss: {val_batch_loss:.3f}')
# Out:
# EPOCH 1:	Training loss: 0.772	Validation loss: 0.743
#
# EPOCH 2:	Training loss: 0.724	Validation loss: 0.700
#
# EPOCH 3:	Training loss: 0.684	Validation loss: 0.663
#
# EPOCH 4:	Training loss: 0.651	Validation loss: 0.633
#
# EPOCH 5:	Training loss: 0.624	Validation loss: 0.608
#
# EPOCH 6:	Training loss: 0.601	Validation loss: 0.587
#
# EPOCH 7:	Training loss: 0.581	Validation loss: 0.569
#
# EPOCH 8:	Training loss: 0.565	Validation loss: 0.554
#
# EPOCH 9:	Training loss: 0.551	Validation loss: 0.541
#
# EPOCH 10:	Training loss: 0.539	Validation loss: 0.530
#
# EPOCH 11:	Training loss: 0.528	Validation loss: 0.520
#
# EPOCH 12:	Training loss: 0.519	Validation loss: 0.511
#
# EPOCH 13:	Training loss: 0.511	Validation loss: 0.504
#
# EPOCH 14:	Training loss: 0.504	Validation loss: 0.497
#
# EPOCH 15:	Training loss: 0.497	Validation loss: 0.491
#
# EPOCH 16:	Training loss: 0.492	Validation loss: 0.485
#
# EPOCH 17:	Training loss: 0.486	Validation loss: 0.481
#
# EPOCH 18:	Training loss: 0.482	Validation loss: 0.476
#
# EPOCH 19:	Training loss: 0.477	Validation loss: 0.472
#
# EPOCH 20:	Training loss: 0.474	Validation loss: 0.468
#
# EPOCH 21:	Training loss: 0.470	Validation loss: 0.465
#
# EPOCH 22:	Training loss: 0.467	Validation loss: 0.461
#
# EPOCH 23:	Training loss: 0.463	Validation loss: 0.458
#
# EPOCH 24:	Training loss: 0.461	Validation loss: 0.456
#
# EPOCH 25:	Training loss: 0.458	Validation loss: 0.453
#
# EPOCH 26:	Training loss: 0.455	Validation loss: 0.450
#
# EPOCH 27:	Training loss: 0.453	Validation loss: 0.448
#
# EPOCH 28:	Training loss: 0.451	Validation loss: 0.446
#
# EPOCH 29:	Training loss: 0.449	Validation loss: 0.444
#
# EPOCH 30:	Training loss: 0.446	Validation loss: 0.442
#
# EPOCH 31:	Training loss: 0.445	Validation loss: 0.440
#
# EPOCH 32:	Training loss: 0.443	Validation loss: 0.438
#
# EPOCH 33:	Training loss: 0.441	Validation loss: 0.436
#
# EPOCH 34:	Training loss: 0.439	Validation loss: 0.435
#
# EPOCH 35:	Training loss: 0.438	Validation loss: 0.433
#
# EPOCH 36:	Training loss: 0.436	Validation loss: 0.432
#
# EPOCH 37:	Training loss: 0.435	Validation loss: 0.430
#
# EPOCH 38:	Training loss: 0.433	Validation loss: 0.429
#
# EPOCH 39:	Training loss: 0.432	Validation loss: 0.427
#
# EPOCH 40:	Training loss: 0.430	Validation loss: 0.426
#
# EPOCH 41:	Training loss: 0.429	Validation loss: 0.425
#
# EPOCH 42:	Training loss: 0.428	Validation loss: 0.424
#
# EPOCH 43:	Training loss: 0.427	Validation loss: 0.422
#
# EPOCH 44:	Training loss: 0.426	Validation loss: 0.421
#
# EPOCH 45:	Training loss: 0.424	Validation loss: 0.420
#
# EPOCH 46:	Training loss: 0.423	Validation loss: 0.419
#
# EPOCH 47:	Training loss: 0.422	Validation loss: 0.418
#
# EPOCH 48:	Training loss: 0.421	Validation loss: 0.417
#
# EPOCH 49:	Training loss: 0.420	Validation loss: 0.416
#
# EPOCH 50:	Training loss: 0.419	Validation loss: 0.415
#
# EPOCH 51:	Training loss: 0.418	Validation loss: 0.414
#
# EPOCH 52:	Training loss: 0.418	Validation loss: 0.413
#
# EPOCH 53:	Training loss: 0.417	Validation loss: 0.412
#
# EPOCH 54:	Training loss: 0.416	Validation loss: 0.412
#
# EPOCH 55:	Training loss: 0.415	Validation loss: 0.411
#
# EPOCH 56:	Training loss: 0.414	Validation loss: 0.410
#
# EPOCH 57:	Training loss: 0.414	Validation loss: 0.409
#
# EPOCH 58:	Training loss: 0.413	Validation loss: 0.408
#
# EPOCH 59:	Training loss: 0.412	Validation loss: 0.408
#
# EPOCH 60:	Training loss: 0.411	Validation loss: 0.407
#
# EPOCH 61:	Training loss: 0.411	Validation loss: 0.406
#
# EPOCH 62:	Training loss: 0.410	Validation loss: 0.406
#
# EPOCH 63:	Training loss: 0.409	Validation loss: 0.405
#
# EPOCH 64:	Training loss: 0.409	Validation loss: 0.404
#
# EPOCH 65:	Training loss: 0.408	Validation loss: 0.404
#
# EPOCH 66:	Training loss: 0.407	Validation loss: 0.403
#
# EPOCH 67:	Training loss: 0.407	Validation loss: 0.403
#
# EPOCH 68:	Training loss: 0.406	Validation loss: 0.402
#
# EPOCH 69:	Training loss: 0.406	Validation loss: 0.401
#
# EPOCH 70:	Training loss: 0.405	Validation loss: 0.401
#
# EPOCH 71:	Training loss: 0.405	Validation loss: 0.400
#
# EPOCH 72:	Training loss: 0.404	Validation loss: 0.400
#
# EPOCH 73:	Training loss: 0.404	Validation loss: 0.399
#
# EPOCH 74:	Training loss: 0.403	Validation loss: 0.399
#
# EPOCH 75:	Training loss: 0.403	Validation loss: 0.398
#
# EPOCH 76:	Training loss: 0.402	Validation loss: 0.398
#
# EPOCH 77:	Training loss: 0.402	Validation loss: 0.397
#
# EPOCH 78:	Training loss: 0.401	Validation loss: 0.397
#
# EPOCH 79:	Training loss: 0.401	Validation loss: 0.396
#
# EPOCH 80:	Training loss: 0.400	Validation loss: 0.396
#
# EPOCH 81:	Training loss: 0.400	Validation loss: 0.396
#
# EPOCH 82:	Training loss: 0.399	Validation loss: 0.395
#
# EPOCH 83:	Training loss: 0.399	Validation loss: 0.395
#
# EPOCH 84:	Training loss: 0.399	Validation loss: 0.394
#
# EPOCH 85:	Training loss: 0.398	Validation loss: 0.394
#
# EPOCH 86:	Training loss: 0.398	Validation loss: 0.393
#
# EPOCH 87:	Training loss: 0.398	Validation loss: 0.393
#
# EPOCH 88:	Training loss: 0.397	Validation loss: 0.393
#
# EPOCH 89:	Training loss: 0.397	Validation loss: 0.392
#
# EPOCH 90:	Training loss: 0.396	Validation loss: 0.392
#
# EPOCH 91:	Training loss: 0.396	Validation loss: 0.392
#
# EPOCH 92:	Training loss: 0.396	Validation loss: 0.391
#
# EPOCH 93:	Training loss: 0.395	Validation loss: 0.391
#
# EPOCH 94:	Training loss: 0.395	Validation loss: 0.391
#
# EPOCH 95:	Training loss: 0.395	Validation loss: 0.390
#
# EPOCH 96:	Training loss: 0.395	Validation loss: 0.390
#
# EPOCH 97:	Training loss: 0.394	Validation loss: 0.390
#
# EPOCH 98:	Training loss: 0.394	Validation loss: 0.389
#
# EPOCH 99:	Training loss: 0.394	Validation loss: 0.389
#
# EPOCH 100:	Training loss: 0.393	Validation loss: 0.389
#
# EPOCH 101:	Training loss: 0.393	Validation loss: 0.389
#
# EPOCH 102:	Training loss: 0.393	Validation loss: 0.388
#
# EPOCH 103:	Training loss: 0.393	Validation loss: 0.388
#
# EPOCH 104:	Training loss: 0.392	Validation loss: 0.388
#
# EPOCH 105:	Training loss: 0.392	Validation loss: 0.388
#
# EPOCH 106:	Training loss: 0.392	Validation loss: 0.387
#
# EPOCH 107:	Training loss: 0.392	Validation loss: 0.387
#
# EPOCH 108:	Training loss: 0.391	Validation loss: 0.387
#
# EPOCH 109:	Training loss: 0.391	Validation loss: 0.387
#
# EPOCH 110:	Training loss: 0.391	Validation loss: 0.386
#
# EPOCH 111:	Training loss: 0.391	Validation loss: 0.386
#
# EPOCH 112:	Training loss: 0.390	Validation loss: 0.386
#
# EPOCH 113:	Training loss: 0.390	Validation loss: 0.386
#
# EPOCH 114:	Training loss: 0.390	Validation loss: 0.385
#
# EPOCH 115:	Training loss: 0.390	Validation loss: 0.385
#
# EPOCH 116:	Training loss: 0.390	Validation loss: 0.385
#
# EPOCH 117:	Training loss: 0.389	Validation loss: 0.385
#
# EPOCH 118:	Training loss: 0.389	Validation loss: 0.385
#
# EPOCH 119:	Training loss: 0.389	Validation loss: 0.384
#
# EPOCH 120:	Training loss: 0.389	Validation loss: 0.384
#
# EPOCH 121:	Training loss: 0.389	Validation loss: 0.384
#
# EPOCH 122:	Training loss: 0.388	Validation loss: 0.384
#
# EPOCH 123:	Training loss: 0.388	Validation loss: 0.384
#
# EPOCH 124:	Training loss: 0.388	Validation loss: 0.383
#
# EPOCH 125:	Training loss: 0.388	Validation loss: 0.383
#
# EPOCH 126:	Training loss: 0.388	Validation loss: 0.383
#
# EPOCH 127:	Training loss: 0.388	Validation loss: 0.383
#
# EPOCH 128:	Training loss: 0.387	Validation loss: 0.383
#
# EPOCH 129:	Training loss: 0.387	Validation loss: 0.382
#
# EPOCH 130:	Training loss: 0.387	Validation loss: 0.382
#
# EPOCH 131:	Training loss: 0.387	Validation loss: 0.382
#
# EPOCH 132:	Training loss: 0.387	Validation loss: 0.382
#
# EPOCH 133:	Training loss: 0.387	Validation loss: 0.382
#
# EPOCH 134:	Training loss: 0.387	Validation loss: 0.382
#
# EPOCH 135:	Training loss: 0.386	Validation loss: 0.382
#
# EPOCH 136:	Training loss: 0.386	Validation loss: 0.381
#
# EPOCH 137:	Training loss: 0.386	Validation loss: 0.381
#
# EPOCH 138:	Training loss: 0.386	Validation loss: 0.381
#
# EPOCH 139:	Training loss: 0.386	Validation loss: 0.381
#
# EPOCH 140:	Training loss: 0.386	Validation loss: 0.381
#
# EPOCH 141:	Training loss: 0.386	Validation loss: 0.381
#
# EPOCH 142:	Training loss: 0.385	Validation loss: 0.380
#
# EPOCH 143:	Training loss: 0.385	Validation loss: 0.380
#
# EPOCH 144:	Training loss: 0.385	Validation loss: 0.380
#
# EPOCH 145:	Training loss: 0.385	Validation loss: 0.380
#
# EPOCH 146:	Training loss: 0.385	Validation loss: 0.380
#
# EPOCH 147:	Training loss: 0.385	Validation loss: 0.380
#
# EPOCH 148:	Training loss: 0.385	Validation loss: 0.380
#
# EPOCH 149:	Training loss: 0.385	Validation loss: 0.380
#
# EPOCH 150:	Training loss: 0.385	Validation loss: 0.379
#
# EPOCH 151:	Training loss: 0.384	Validation loss: 0.379
#
# EPOCH 152:	Training loss: 0.384	Validation loss: 0.379
#
# EPOCH 153:	Training loss: 0.384	Validation loss: 0.379
#
# EPOCH 154:	Training loss: 0.384	Validation loss: 0.379
#
# EPOCH 155:	Training loss: 0.384	Validation loss: 0.379
#
# EPOCH 156:	Training loss: 0.384	Validation loss: 0.379
#
# EPOCH 157:	Training loss: 0.384	Validation loss: 0.379
#
# EPOCH 158:	Training loss: 0.384	Validation loss: 0.379
#
# EPOCH 159:	Training loss: 0.384	Validation loss: 0.378
#
# EPOCH 160:	Training loss: 0.383	Validation loss: 0.378
#
# EPOCH 161:	Training loss: 0.383	Validation loss: 0.378
#
# EPOCH 162:	Training loss: 0.383	Validation loss: 0.378
#
# EPOCH 163:	Training loss: 0.383	Validation loss: 0.378
#
# EPOCH 164:	Training loss: 0.383	Validation loss: 0.378
#
# EPOCH 165:	Training loss: 0.383	Validation loss: 0.378
#
# EPOCH 166:	Training loss: 0.383	Validation loss: 0.378
#
# EPOCH 167:	Training loss: 0.383	Validation loss: 0.378
#
# EPOCH 168:	Training loss: 0.383	Validation loss: 0.378
#
# EPOCH 169:	Training loss: 0.383	Validation loss: 0.378
#
# EPOCH 170:	Training loss: 0.383	Validation loss: 0.377
#
# EPOCH 171:	Training loss: 0.383	Validation loss: 0.377
#
# EPOCH 172:	Training loss: 0.382	Validation loss: 0.377
#
# EPOCH 173:	Training loss: 0.382	Validation loss: 0.377
#
# EPOCH 174:	Training loss: 0.382	Validation loss: 0.377
#
# EPOCH 175:	Training loss: 0.382	Validation loss: 0.377
#
# EPOCH 176:	Training loss: 0.382	Validation loss: 0.377
#
# EPOCH 177:	Training loss: 0.382	Validation loss: 0.377
#
# EPOCH 178:	Training loss: 0.382	Validation loss: 0.377
#
# EPOCH 179:	Training loss: 0.382	Validation loss: 0.377
#
# EPOCH 180:	Training loss: 0.382	Validation loss: 0.377
#
# EPOCH 181:	Training loss: 0.382	Validation loss: 0.377
#
# EPOCH 182:	Training loss: 0.382	Validation loss: 0.376
#
# EPOCH 183:	Training loss: 0.382	Validation loss: 0.376
#
# EPOCH 184:	Training loss: 0.382	Validation loss: 0.376
#
# EPOCH 185:	Training loss: 0.382	Validation loss: 0.376
#
# EPOCH 186:	Training loss: 0.382	Validation loss: 0.376
#
# EPOCH 187:	Training loss: 0.381	Validation loss: 0.376
#
# EPOCH 188:	Training loss: 0.381	Validation loss: 0.376
#
# EPOCH 189:	Training loss: 0.381	Validation loss: 0.376
#
# EPOCH 190:	Training loss: 0.381	Validation loss: 0.376
#
# EPOCH 191:	Training loss: 0.381	Validation loss: 0.376
#
# EPOCH 192:	Training loss: 0.381	Validation loss: 0.376
#
# EPOCH 193:	Training loss: 0.381	Validation loss: 0.376
#
# EPOCH 194:	Training loss: 0.381	Validation loss: 0.376
#
# EPOCH 195:	Training loss: 0.381	Validation loss: 0.376
#
# EPOCH 196:	Training loss: 0.381	Validation loss: 0.375
#
# EPOCH 197:	Training loss: 0.381	Validation loss: 0.375
#
# EPOCH 198:	Training loss: 0.381	Validation loss: 0.375
#
# EPOCH 199:	Training loss: 0.381	Validation loss: 0.375
#
# EPOCH 200:	Training loss: 0.381	Validation loss: 0.375

# %% [markdown]
# ##10. Đánh giá mô hình

# %%
val_set_acc = compute_accuracy(X_val, y_val, theta)
test_set_acc = compute_accuracy(X_test, y_test, theta)

print('Evaluation on validation and test set:')
print(f'Accuracy (Validation): {val_set_acc}')
print(f'Accuracy (Test): {test_set_acc}')
# Out:
# Evaluation on validation and test set:
# Accuracy (Validation): 0.8207070707070707
# Accuracy (Test): 0.8396464646464646
